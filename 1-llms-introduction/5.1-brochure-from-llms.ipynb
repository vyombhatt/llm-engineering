# %% [markdown]
# ### A full business solution
#
# Now we will take our project from Day 1 to the next level
#
# **Business Challenge**:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ### First step: Have GPT-4o-mini figure out which links are relevant
#
# **Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.**
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/black-forest-labs/FLUX.1-Kontext-dev',
#  '/tencent/Hunyuan-A13B-Instruct',
#  '/google/gemma-3n-E4B-it',
#  '/THUDM/GLM-4.1V-9B-Thinking',
#  '/OmniGen2/OmniGen2',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/black-forest-labs/FLUX.1-Kontext-Dev',
#  '/spaces/ilcve21/Sparc3D',
#  '/spaces/OmniGen2/OmniGen2',
#  '/spaces/tencent/Hunyuan3D-2.1',
#  '/spaces',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/facebook/seamless-interaction',
#  '/datasets/HuggingFaceFW/fineweb-2',
#  '/datasets/FreedomIntelligence/ShareGPT-4o-Image',
#  '/datasets/black-forest-labs/kontext-bench',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord',
#  'https://www.zhihu.com/org/huggingface',
#  'https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/blog/chinese-language-blog/wechat.jpg']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blog', 'url': 'https://huggingface.co/blog'},
#   {'type': 'company page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'models page', 'url': 'https://huggingface.co/models'},
#   {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'},
#   {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'},
#   {'type': 'documentation page', 'url': 'https://huggingface.co/docs'},
#   {'type': 'community discussions', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ### Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# black-forest-labs/FLUX.1-Kontext-dev
# Updated
# 7 days ago
# •
# 144k
# •
# 1.27k
# tencent/Hunyuan-A13B-Instruct
# Updated
# 2 days ago
# •
# 9.23k
# •
# 699
# google/gemma-3n-E4B-it
# Updated
# about 22 hours ago
# •
# 175k
# •
# 419
# THUDM/GLM-4.1V-9B-Thinking
# Updated
# 1 day ago
# •
# 4.12k
# •
# 181
# OmniGen2/OmniGen2
# Updated
# 10 days ago
# •
# 34.6k
# •
# 337
# Browse 1M+ models
# Spaces
# Running
# 9.19k
# 9.19k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# MCP
# 516
# 516
# FLUX.1 Kontext
# ⚡
# Kontext image editing on FLUX[dev]
# Running
# 1.02k
# 1.02k
# Sparc3D
# 🏃
# Next-Gen High-Resolution 3D Model Generation
# Running
# on
# Zero
# 363
# 363
# OmniGen2
# 👀
# OmniGen2: Unified Image Understanding and Generation.
# Running
# on
# Zero
# 612
# 612
# Hunyuan3D-2.1
# 👻
# Image-to-3D Generation
# Browse 400k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 22.9k
# •
# 8.15k
# facebook/seamless-interaction
# Updated
# 7 days ago
# •
# 1
# •
# 75
# HuggingFaceFW/fineweb-2
# Updated
# 7 days ago
# •
# 38.3k
# •
# 557
# FreedomIntelligence/ShareGPT-4o-Image
# Updated
# 3 days ago
# •
# 75
# •
# 66
# black-forest-labs/kontext-bench
# Updated
# 8 days ago
# •
# 32
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 766 models
# •
# 3.52k followers
# AI at Meta
# Enterprise
# company
# •
# 2.17k models
# •
# 6.7k followers
# Amazon
# company
# •
# 20 models
# •
# 3.27k followers
# Google
# Enterprise
# company
# •
# 1.01k models
# •
# 18.6k followers
# Intel
# company
# •
# 206 models
# •
# 2.7k followers
# Microsoft
# company
# •
# 396 models
# •
# 13.3k followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 166 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 309 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 146,433
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,639
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,338
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,734
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,864
# Fast tokenizers optimized for research & production
# TRL
# 14,448
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,977
# State-of-the-art ML running directly in your browser
# smolagents
# 20,900
# Smol library to build great agents in Python
# PEFT
# 18,937
# Parameter-efficient finetuning for large language models
# Datasets
# 20,331
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,286
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,898
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
# Zhihu
# WeChat
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 46,833
# AI & ML interests
# The AI community building the future.
# Recent Activity
# fracapuano
# updated
# a dataset
# about 2 hours ago
# huggingface/documentation-images
# Wauplin
# updated
# a dataset
# about 18 hours ago
# huggingface/documentation-images
# stevhliu
# new
# activity
# about 19 hours ago
# huggingface/documentation-images:
# Upload marianmt-attn-mask.png to merge
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 46
# Team members
# 213
# +179
# +166
# +145
# +135
# +115
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 218k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 8.32M
# •
# •
# 718
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 1.08M
# •
# 198
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.56M
# •
# •
# 787
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 218k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 8.32M
# •
# •
# 718
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 1.08M
# •
# 198
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.56M
# •
# •
# 787
# spaces
# 29
# Sort:
# 		Recently updated
# pinned
# Running
# 14
# Enterprise Hub
# 🔒
# Why you need it, how to get it
# huggingface
# 7 days ago
# pinned
# Running
# on
# CPU Upgrade
# 12
# Hugging Face Fast
# 🏎
# Test your internet connection speed
# huggingface
# 22 days ago
# pinned
# Running
# 94
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 184
# Inference Playground
# 🔋
# Toggle dark/light theme on Hugging Face Playground
# huggingface
# 16 days ago
# Running
# on
# CPU Upgrade
# 13
# Openapi
# 🦀
# Hub API Documentation
# huggingface
# 16 days ago
# Running
# 438
# AI Deadlines
# ⚡
# Organize project deadlines with AI assistance
# huggingface
# 26 days ago
# View 29
# 							Spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# 0.0B
# •
# Updated
# May 24
# •
# 4.09k
# •
# 22
# huggingface/timesfm-tourism-monthly
# 0.0B
# •
# Updated
# Mar 31
# •
# 21
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 2.22k
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# 7B
# •
# Updated
# Jun 14, 2023
# •
# 40
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 33.8k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# 0.1B
# •
# Updated
# Mar 22, 2023
# •
# 247
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 33.6k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 16
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 99.4k
# •
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# View 16
# 							models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 2 hours ago
# •
# 52
# •
# 3M
# •
# 72
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 7 days ago
# •
# 1.73k
# •
# 2.14k
# •
# 26
# huggingface/cats-image
# Viewer
# •
# Updated
# 14 days ago
# •
# 1
# •
# 9.88k
# •
# 2
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 20 days ago
# •
# 70
# •
# 544
# •
# 7
# huggingface/label-files
# Updated
# 22 days ago
# •
# 2.09k
# •
# 18
# huggingface/policy-docs
# Viewer
# •
# Updated
# about 1 month ago
# •
# 24
# •
# 2.31k
# •
# 11
# huggingface/electricity-production
# Viewer
# •
# Updated
# May 22
# •
# 397
# •
# 124
# •
# 1
# huggingface/badges
# Viewer
# •
# Updated
# Apr 8
# •
# 1
# •
# 1.39M
# •
# 45
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 252
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 335
# View 34
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Team & Enterprise Hub
# Scale your organization with the world’s leading AI platform
# Subscribe to
# Team
# starting at $20/user/month
# or
# Contact sales for
# Enterprise
# to explore flexible contract options
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Inference Providers
# Enable organization billing for Inference Providers, monitor usage with analytics, and manage spending limits.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Team
# starting at $20/user/month
# or
# Contact sales for
# Enterprise
# to explore flexible contract options
# Google
# Enterprise
# company
# •
# 1.01k models
# •
# 18.6k followers
# Shopify
# Enterprise
# company
# •
# 492 followers
# AMD
# Enterprise
# company
# •
# 145 models
# •
# 1.64k followers
# JetBrains
# Team
# company
# •
# 10 models
# •
# 598 followers
# Together
# Team
# company
# •
# 33 models
# •
# 637 followers
# Xsolla
# Enterprise
# company
# •
# 144 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 111 followers
# Jusbrasil
# Team
# company
# •
# 98 followers
# creditkarma
# Enterprise
# company
# •
# 74 followers
# H2O.ai
# Team
# company
# •
# 71 models
# •
# 433 followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 166 followers
# MiniMax
# Team
# company
# •
# 10 models
# •
# 1.45k followers
# Liquid AI
# Team
# company
# •
# 214 followers
# MiroMind AI
# Team
# company
# •
# 39 followers
# NVIDIA
# Enterprise
# company
# •
# 422 models
# •
# 30.8k followers
# AI at Meta
# Enterprise
# company
# •
# 2.17k models
# •
# 6.7k followers
# Snowflake
# Enterprise
# company
# •
# 23 models
# •
# 553 followers
# Arm
# Enterprise
# company
# •
# 226 followers
# Qwen
# Team
# company
# •
# 321 models
# •
# 37.1k followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 290 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 158 followers
# TNG Technology Consulting GmbH
# Team
# company
# •
# 5 models
# •
# 188 followers
# Technology Innovation Institute
# Team
# company
# •
# 101 models
# •
# 1.47k followers
# BAIDU
# Team
# company
# •
# 23 models
# •
# 794 followers
# Chegg Inc
# Enterprise
# company
# •
# 87 followers
# LinkedIn
# Enterprise
# company
# •
# 65 followers
# Lightricks
# Team
# company
# •
# 13 models
# •
# 1.1k followers
# BCG X
# Team
# company
# •
# 40 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 50.9k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 303 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 245 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 309 followers
# ServiceNow
# Enterprise
# company
# •
# 517 followers
# Toyota Research Institute
# Team
# company
# •
# 10 models
# •
# 124 followers
# Fidelity Investments
# Enterprise
# company
# •
# 151 followers
# IBM Granite
# Team
# company
# •
# 125 models
# •
# 2k followers
# Aledade Inc
# Enterprise
# +
# company
# •
# 72 followers
# HyperCLOVA X
# Team
# company
# •
# 3 models
# •
# 393 followers
# HiddenLayer
# Team
# company
# •
# 1 model
# •
# 74 followers
# Roblox Corporation
# Enterprise
# company
# •
# 3 models
# •
# 248 followers
# Twelve Labs
# Team
# company
# •
# 50 followers
# Novo Nordisk R&ED
# Team
# company
# •
# 37 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Give your personal account or your organization the most advanced platform to build AI.
# PRO
# PRO Account
# Boost your personal HF experience
# Subscribe for
# $9
# per month
# Get PRO
# 10× private storage capacity
# 20× included inference credits
# 8× ZeroGPU quota and highest queue priority
# Spaces Dev Mode & ZeroGPU Spaces hosting
# Publish blog articles on your HF profile
# Dataset Viewer for private datasets
# Show your support with a Pro badge
# Team
# Instant setup for growing teams
# Subscribe for
# $20
# per user per month
# Get Team (via credit card)
# SSO and SAML support
# Choose data location with Storage Regions
# Detailed action reviews with Audit Logs
# Granular access control via Resource Groups
# Repository usage Analytics
# Set auth policies and default repository visibility
# Centralized token control and approvals
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# All organization members get ZeroGPU and Inference Providers PRO benefits
# Enterprise
# Custom onboarding and enterprise features
# Starting at
# $50
# per user per month
# Contact Sales
# All benefits from the Team plan
# Managed billing with annual commitments
# Legal and Compliance processes
# Personalized support
# Need support to adopt the HF Hub in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $2.50
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# ZeroGPU
# dynamic
# dynamic
# Nvidia H200
# 70 GB
# FREE
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $2.50
# 2
# 160GB
# $5.00
# 4
# 320GB
# $10.00
# 8
# 640GB
# $20.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# PRO Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get PRO
# ($9/month)
# Inference Providers
# : Get 20× included inference credits
# ZeroGPU
# : Get 8× usage quota and highest priority in queues
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Dataset Viewer
# : Activate and use it on private datasets
# Blog Articles
# : Publish articles on your HF profile
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Training and Finetuning Sparse Embedding Models with Sentence Transformers v5
# By
# tomaarsen
# July 1, 2025
# •
# 69
# Community Articles
# view all
# Bringing Fusion Down to Earth: ML for Stellarator Optimization
# By
# cgeorgiaw
# •
# 2 days ago
# •
# 53
# Welcome the NVIDIA Llama Nemotron Nano VLM to Hugging Face Hub
# By
# nvidia
# and 10 others
# •
# 7 days ago
# •
# 23
# Teaching Data Literacy with Hugging Face's AI Sheets
# By
# ParulPandey
# •
# 4 days ago
# •
# 23
# Common Pitfalls in Sharing Open Source Models on Hugging Face (and How to Dodge Them)
# By
# FriendliAI
# and 2 others
# •
# 3 days ago
# •
# 20
# Automated Discovery of High-Performance GPU Kernels with OpenEvolve
# By
# codelion
# •
# 6 days ago
# •
# 16
# Understanding Gemma 3n: How MatFormer Gives You Many Models in One
# By
# rishiraj
# •
# 8 days ago
# •
# 18
# Why We Built the OpenMDW License: A Comprehensive License for ML Models
# By
# linuxfoundation
# •
# 2 days ago
# •
# 10
# IFAD AI Benchmark (Garden V1)
# By
# ifadaiml
# and 8 others
# •
# 4 days ago
# •
# 9
# Should We Still Pretrain Encoders with Masked Language Modeling?
# By
# Nicolas-BZRD
# and 3 others
# •
# 2 days ago
# •
# 9
# How Much Power does a SOTA Open Video Model Use? ⚡🎥
# By
# jdelavande
# and 2 others
# •
# 2 days ago
# •
# 8
# LLMs recognise bias but also reproduce harmful stereotypes: an analysis of bias in leading LLMs
# By
# davidberenstein1957
# and 3 others
# •
# 2 days ago
# •
# 7
# Combining Remote Reasoning with Local Models
# By
# burtenshaw
# •
# 8 days ago
# •
# 11
# ⚡ nano-vLLM: Lightweight, Low-Latency LLM Inference from Scratch
# By
# zamal
# •
# 6 days ago
# •
# 6
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 270
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 174
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 302
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 347
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# Jan 12
# •
# 77
# Everything You Need to Know about Knowledge Distillation
# By
# Kseniase
# and 1 other
# •
# Mar 6
# •
# 32
# 🤔👀🎬🖥️📖 Kimi-VL-A3B-Thinking-2506: A Quick Navigation
# By
# moonshotai
# and 1 other
# •
# 13 days ago
# •
# 55
# Gemma 3n fully available in the open-source ecosystem!
# By
# ariG23498
# June 26, 2025
# •
# 96
# Transformers backend integration in SGLang
# By
# marcsun13
# June 23, 2025
# •
# 41
# (LoRA) Fine-Tuning FLUX.1-dev on Consumer Hardware
# By
# derekl35
# June 19, 2025
# •
# 70
# Groq on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# June 16, 2025
# •
# 36
# Enhance Your Models in 5 Minutes with the Hugging Face Kernel Hub
# By
# drbh
# June 12, 2025
# •
# 104
# Featherless AI on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# June 12, 2025
# •
# 43
# Introducing Training Cluster as a Service - a new collaboration with NVIDIA
# By
# jeffboudier
# June 11, 2025
# •
# 23
# ScreenSuite - The most comprehensive evaluation suite for GUI Agents!
# By
# a-mahla
# June 6, 2025
# •
# 49
# KV Cache from scratch in nanoVLM
# By
# ariG23498
# June 4, 2025
# •
# 81
# SmolVLA: Efficient Vision-Language-Action Model trained on Lerobot Community Data
# By
# danaaubakirova
# June 3, 2025
# •
# 174
# No GPU left behind: Unlocking Efficiency with Co-located vLLM in TRL
# By
# toslali-ibm
# June 3, 2025
# guest
# •
# 63
# CodeAgents + Structure: A Better Way to Execute Actions
# By
# akseljoonas
# May 28, 2025
# •
# 63
# 🐯 Liger GRPO meets TRL
# By
# shisahni
# May 25, 2025
# guest
# •
# 44
# Dell Enterprise Hub is all you need to build AI on premises
# By
# jeffboudier
# May 23, 2025
# •
# 19
# Previous
# 1
# 2
# 3
# ...
# 43
# Next
# Community Articles
# Sort:
# 		Trending
# Bringing Fusion Down to Earth: ML for Stellarator Optimization
# By
# cgeorgiaw
# •
# 2 days ago
# •
# 53
# Welcome the NVIDIA Llama Nemotron Nano VLM to Hugging Face Hub
# By
# nvidia
# and 10 others
# •
# 7 days ago
# •
# 23
# Teaching Data Literacy with Hugging Face's AI Sheets
# By
# ParulPandey
# •
# 4 days ago
# •
# 23
# Common Pitfalls in Sharing Open Source Models on Hugging Face (and How to Dodge Them)
# By
# FriendliAI
# and 2 others
# •
# 3 days ago
# •
# 20
# Automated Discovery of High-Performance GPU Kernels with OpenEvolve
# By
# codelion
# •
# 6 days ago
# •
# 16
# Understanding Gemma 3n: How MatFormer Gives You Many Models in One
# By
# rishiraj
# •
# 8 days ago
# •
# 18
# Why We Built the OpenMDW License: A Comprehensive License for ML Models
# By
# linuxfoundation
# •
# 2 days ago
# •
# 10
# IFAD AI Benchmark (Garden V1)
# By
# ifadaiml
# and 8 others
# •
# 4 days ago
# •
# 9
# Should We Still Pretrain Encoders with Masked Language Modeling?
# By
# Nicolas-BZRD
# and 3 others
# •
# 2 days ago
# •
# 9
# How Much Power does a SOTA Open Video Model Use? ⚡🎥
# By
# jdelavande
# and 2 others
# •
# 2 days ago
# •
# 8
# LLMs recognise bias but also reproduce harmful stereotypes: an analysis of bias in leading LLMs
# By
# davidberenstein1957
# and 3 others
# •
# 2 days ago
# •
# 7
# Combining Remote Reasoning with Local Models
# By
# burtenshaw
# •
# 8 days ago
# •
# 11
# ⚡ nano-vLLM: Lightweight, Low-Latency LLM Inference from Scratch
# By
# zamal
# •
# 6 days ago
# •
# 6
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 270
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 174
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 302
# Fine-tune Llama 3.1 Ultra-Efficiently with Unsloth
# By
# mlabonne
# •
# Jul 29, 2024
# •
# 347
# Mastering Tensor Dimensions in Transformers
# By
# not-lain
# •
# Jan 12
# •
# 77
# Everything You Need to Know about Knowledge Distillation
# By
# Kseniase
# and 1 other
# •
# Mar 6
# •
# 32
# 🤔👀🎬🖥️📖 Kimi-VL-A3B-Thinking-2506: A Quick Navigation
# By
# moonshotai
# and 1 other
# •
# 13 days ago
# •
# 55
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community forum
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Apollo Video Understanding Models
# Beginners
# 1
# 9
# July 4, 2025
# Controlling AI's determinism - Score
# Research
# 2
# 10
# July 4, 2025
# Are InferenceClient()'s down?
# Beginners
# 10
# 171
# July 3, 2025
# Word level tokenizer pulls special tokens out of pretokenized strings
# 🤗Tokenizers
# 1
# 11
# July 4, 2025
# [License Agreement Error] runwayml/stable-diffusion-v1-5 returns 404
# Models
# 2
# 19
# July 3, 2025
# Handling outlier and weak correlation in ANN
# Beginners
# 1
# 5
# July 4, 2025
# “Failed to fetch” Error when Running Compute on intfloat/multilingual-e5-largen Inference Providers
# Models
# 1
# 14
# July 4, 2025
# No (0) models returned by 'Text2Text' search filter
# Site Feedback
# 3
# 32
# July 3, 2025
# An hour of silent building
# Beginners
# 1
# 27
# July 3, 2025
# Symbolic Architecture Is the Future of AI
# Research
# 42
# 201
# July 4, 2025
# Create tags / keywords from text
# Beginners
# 3
# 3698
# July 3, 2025
# Is it possible to get multiple rows at once via Streaming?
# Beginners
# 1
# 12
# July 3, 2025
# Video and picture making ai
# Beginners
# 3
# 53
# July 2, 2025
# Spaces category filters
# Spaces
# 2
# 14
# July 2, 2025
# Have you guys noticed the new trend?
# Research
# 11
# 226
# July 2, 2025
# Alot of questions, or, How can i run models locally (for an absolute begginger)
# Beginners
# 3
# 21
# July 4, 2025
# Dummy_agent_library.ipynb not working for me
# Course
# 5
# 89
# July 3, 2025
# Adding atomic / indivisible tokens to BPE tokenizer
# 🤗Tokenizers
# 8
# 19
# July 3, 2025
# Downloads data not updating？
# 🤗Hub
# 10
# 78
# July 2, 2025
# RSOS: Emergent Symbolic Recursion in GPT-4
# Research
# 14
# 286
# July 3, 2025
# Ai conscious base
# Research
# 7
# 59
# July 2, 2025
# Debugging Custom Stable Diffusion Pipeline for 1D Signal Generation
# 🧨 Diffusers
# 1
# 13
# July 2, 2025
# Looking to connect w/ the creator(s) of Kokoro
# Models
# 2
# 21
# July 3, 2025
# Help with ClamAV Error in Hugging Face Space
# Beginners
# 5
# 58
# July 1, 2025
# Forcing Offline mode for hugging face embeddings in docker container is slow
# Beginners
# 1
# 13
# July 2, 2025
# You have exceeded your monthly included credits for Inference Providers
# Course
# 2
# 19
# July 1, 2025
# How to create multiple MCP server hosted on single endpoint with different Routes
# Intermediate
# 4
# 115
# July 2, 2025
# Using DeepSite in Pipeline
# Models
# 1
# 13
# July 2, 2025
# Which model is best for redrawing illustrations in TikZ?
# Community Calls
# 1
# 17
# July 1, 2025
# Gradio App: 'Application does not seem to be initialized' error on Hugging Face Space (Model loads successfully, but server fails to start)
# Beginners
# 3
# 17
# July 2, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# Appearance settings
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Models
# New
# Manage and compare prompts
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Resetting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# Sponsor
# 50.9k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 1
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# Python
# 146k
# 29.5k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 29.6k
# 6.1k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.3k
# 2.9k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18.9k
# 1.9k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.9k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 3k
# 556
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# Makefile
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 331 repositories
# chat-ui
# Public
# Open source codebase powering the HuggingChat app
# huggingface/chat-ui’s past year of commit activity
# TypeScript
# 8,921
# Apache-2.0
# 1,370
# 319
# (1 issue needs help)
# 18
# Updated
# Jul 4, 2025
# transformers
# Public
# 🤗 Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# huggingface/transformers’s past year of commit activity
# Python
# 146,436
# Apache-2.0
# 29,522
# 1,077
# (2 issues need help)
# 792
# Updated
# Jul 4, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 15,500
# Apache-2.0
# 2,086
# 302
# 187
# Updated
# Jul 4, 2025
# huggingface_hub
# Public
# The official Python client for the Huggingface Hub.
# huggingface/huggingface_hub’s past year of commit activity
# Python
# 2,734
# Apache-2.0
# 746
# 167
# (4 issues need help)
# 12
# Updated
# Jul 4, 2025
# kernel-builder
# Public
# 👷 Build compute kernels
# huggingface/kernel-builder’s past year of commit activity
# Rust
# 70
# 8
# 6
# 3
# Updated
# Jul 4, 2025
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 14,448
# Apache-2.0
# 2,012
# 418
# 87
# Updated
# Jul 4, 2025
# hf-endpoints-documentation
# Public
# huggingface/hf-endpoints-documentation’s past year of commit activity
# 17
# 13
# 0
# 1
# Updated
# Jul 4, 2025
# huggingface.js
# Public
# Use Hugging Face with JavaScript
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 2,161
# MIT
# 448
# 105
# (5 issues need help)
# 61
# Updated
# Jul 4, 2025
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# huggingface/optimum’s past year of commit activity
# Python
# 2,964
# Apache-2.0
# 556
# 268
# (2 issues need help)
# 41
# Updated
# Jul 4, 2025
# inference-playground
# Public
# huggingface/inference-playground’s past year of commit activity
# Svelte
# 42
# MIT
# 3
# 0
# 1
# Updated
# Jul 4, 2025
# View all repositories
# People
# View all
# Sponsoring
# Top languages
# Python
# Jupyter Notebook
# TypeScript
# Rust
# MDX
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# GitHub Sponsor
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 568 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Gradio
# 66,557 followers
# 22h
# Edited
# Report this post
# 🏆
# SambaNova Systems
# Choice Award Winner!
#
# Caption Creator Pro wins $500 in cash prize!
#
# 📸 AI-powered Instagram caption generator
# ⚡ 2s generation with Llama-4-Maverick
# 🌍 Multi-language support
# 🎯 64 style combinations
#
# Built with @SambaNovaAI's latest models!
# Try Caption Creator PRO here:
# https://lnkd.in/gig8iQ2s
# 39
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# João Gante
# ML (generation) @ Hugging Face 🤗
# 19h
# Report this post
# LET'S GO! Cursor using local 🤗 transformers models! You can now test ANY transformers-compatible LLM against your codebase.
#
# From hacking to production, it takes only a few minutes: anything `transformers` does, you can serve into your app 🔥
#
# We've iterated on our local `transformers serve`, a server with `transformers` backend, and it now supports more advanced requests -- including the requests from Cursor.
#
# Testing new models, quantization methods, KV caches, decoding methods, (...) should be much easier now 🫶
#
# Here's a demo with Qwen3 4B:
# (instructions to replicate in a comment)
# …more
# 305
# 9 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 1d
# Report this post
# A nice walkthrough through the recent OpenMDW license by the
# The Linux Foundation
# , a license dedicated to ML models:
# 46
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Pablo Montalvo
# Machine Learning Engineer @ 🤗
# 1d
# Report this post
# 𝐕𝐋𝐌𝐬 𝐧𝐞𝐞𝐝 𝐭𝐨 𝐛𝐞 𝐮𝐧𝐛𝐥𝐨𝐚𝐭𝐞𝐝!
# Ran Gemma 3n through a quick “bloatedness” visualisation, you can see on the graph how much code is scaffolding, even for a super clean & recent release.
#
# We are already tackling this at 🤗 : 𝚝𝚛𝚊𝚗𝚜𝚏𝚘𝚛𝚖𝚎𝚛𝚜 and dubbed it “The great unbloating”. The core PRs merged for this, among other things, move generic utils out of modeling files, updated linting, and overall prep a much, much slimmer v5.
#
# Ideally I'd like to divide by 10 the loc count of VLM modeling files 👀 while keeping the hackability of the library's initial design. I'm getting started with the very popular InternVL and Gemma3n.
#  WDYT? What's your biggest pain point for VLM design/usage right now?
# 230
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 2d
# Edited
# Report this post
# We present `flux-fast`, a hackable repository of recipes to speed up Flux (Dev, Schnell, and Kontext) by upto ~2.5x 🔥
#
# While we primarily targeted H100s, thanks to the community, the repository now also supports AMD cards 🎛️
#
# Our motivation was to introduce minimal and simple changes and test their effectiveness as a function of inference speed. Here's an overview of what we did:
#
# 👉 Making sure the models being compiled are set up for success through `torch.compile()`. We do this by ensuring the models don't have any graph-breaks, recompilation triggers, etc.
# 👉 Flash Attention v3 (FA3) with (unscaled) conversion of inputs to torch.float8_e4m3fn.
# 👉 Dynamic FP8 through TorchAO.
# 👉 Eliminating the device-to-host syncs from the inference pipelines.
#
# We also show you how to enable CUDAGraphs when using `
# torch.export
# ` so that kernel launches aren't delayed.
#
# There are obviously other pieces of stuff that one could optimize:
#
# 🧠 Cache embeddings that don't change during denoising (`guidance_embedding`, `context_embedding`).
# 🧠 Fusing scheduler `step()` with DiT forward to avail more compilation benefits.
#
# It was fun collaborating with
# Joel Schlosser
# on this project. We invite you to check out the codebase, hack into it, and apply the recipes to your favorite pipeline:
# https://lnkd.in/gjV4YXMu
# 151
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Vaibhav Srivastav
# whatever needs doing @ Hugging Face
# 1d
# Report this post
# Yo yo! We're organising a small event to bring together the brightest minds in Paris next week! 🤗
#
# Sign up here:
# https://lu.ma/ft1jex37
# Psyched to put this together with
# SambaNova Systems
# , >Commit and
# The Linux Foundation
# ⚡
#
# Join us for an evening of fun conversations and good food! 💥
# 31
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning @ 🤗 Hugging Face
# 2d
# Report this post
# The Hugging Face hub is shaping up to be the ultimate MCP gateway. This is what it now adds to your AI assistant:
#
# + generative and utility tools via spaces like image generation
# + hub search for models, datasets, and spaces
# + docs search so your AI can understand all Hugging Face libraries
#
# Just plug in Claude Desktop, Cursor, or VSCode into the hub!
# 261
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗
# 4d
# Report this post
# so many multimodal releases these days 🤠
# > ERNIE-4.5-VL: new vision language MoE models by Baidu
# > llama-nemoretriever-colembed: new visual document retrievers by NVIDIA (sota on ViDoRe!)
# > Ovis-3b: new image-text in image-text out models by Alibaba ⤵️
# find them in comments 💬
# 223
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Julien Chaumond
# CTO at Hugging Face
# 2d
# Report this post
# I have bittersweet news to share. 😢
#
# We are closing down huggingchat for now.
#
# Huggingchat was launched in April 2023 when ChatGPT was just 5 months old and it was still quite hard to deploy a similar service. The goal of this app was to showcase that it was now possible to build an open source alternative to ChatGPT, building on top of the community's models and building blocks. 💪
#
# We also built Huggingchat as a testbed to optimize inference which led to the creation of text-generation-inference, which in turn led to HF contributions to SGLang, vLLM,
# llama.cpp
# , and other LLM runtime engines since then.
#
# In the past 27 months we've launched:
# - 🧙 Assistants, an easy way to bundle a prompt, a model, and some tools into an easily-shareable URL you can send your friends
# - 🛠️ HuggingChat Tools, exposing the full ecosystem of
# Gradio
# Spaces straight from within the chat interface
# - 💬 Many model launches were supported on HuggingChat: from OpenAssistant and all the LLamas, Phi-4, to Qwen, DeepSeek, Gemma.... 🔥
#
# The app has always been free and experimental. We are closing it to make room for something new and more integrated with the HF ecosystem. You can export your past conversations as a zip file to load them into another interface.
#
# 💡 If you are looking for a cool alternative interface you should take a look at:
# -
# LibreChat
# from
# Danny Avila
# and team: a clean and simple yet feature-packed chat interface
# -
# Open WebUI
# –
# Tim Jaeryang Baek
# – does it even need an intro anymore?
# - Scira MCP, an up and coming MCP-centric chat interface from Zaid Mukaddam
#
# 💟
# 1,704
# 59 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 2d
# Report this post
# Help us revolutionize MCP development 🚀
#
# We want
# Gradio
# to be the easiest and best way to build and deploy MCP servers. Your input is critical!
#
# New to Gradio for MCP? We'd love for you to try building a server and tell us what you think!
#
# Already tried it? Please share what's working well and what could be improved.
#
# 🔗 Get Started/Learn More:
# https://lnkd.in/ezzka4df
# 💭 Share Feedback Here (or on GitHub):
# https://lnkd.in/ejpc4c-T
# Building Mcp Server With Gradio
# gradio.app
# 71
# 7 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Welcome
# Email or phone
# Password
# Show
# Forgot password?
# Continue
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussion page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nblack-forest-labs/FLUX.1-Kontext-dev\nUpdated\n7 days ago\n•\n144k\n•\n1.27k\ntencent/Hunyuan-A13B-Instruct\nUpdated\n2 days ago\n•\n9.23k\n•\n699\ngoogle/gemma-3n-E4B-it\nUpdated\nabout 22 hours ago\n•\n175k\n•\n419\nTHUDM/GLM-4.1V-9B-Thinking\nUpdated\n1 day ago\n•\n4.12k\n•\n181\nOmniGen2/OmniGen2\nUpdated\n10 days ago\n•\n34.6k\n•\n337\nBrowse 1M+ models\nSpaces\nRunning\n9.19k\n9.19k\nDeepSite v2\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\nMCP\n516\n516\nFLUX.1 Kontext\n⚡\nKontext image editing on FLUX[dev]\nRunning\n1.02k\n1.02k\nSparc3D\n🏃\nNext-Gen High-Resolution 3D Model Generation\nRunning\non\nZero\n363\n363\nOmniGen2\n👀\nOmniGen2: Unified Image Understanding and Generation.\nRunning\non\nZero\n612\n612\nHunyuan3D-2.1\n👻\nImage-to-3D Generation\nBrowse 400k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n22.9k\n•\n8.15k\nfacebook/seamless-interaction\nUpdated\n7 days ago\n•\n1\n•\n75\nHuggingFaceFW/fineweb-2\nUpdated\n7 days ago\n•\n38.3k\n•\n557\nFreedomIntelligence/ShareGPT-4o-Image\nUpdated\n3 days ago\n•\n75\n•\n66\nblack-forest-labs/kontext-bench\nUpdated\n8 days ago\n•\n32\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nTeam & Enterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n766 models\n•\n3.52k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.17k models\n•\n6.7k followers\nAmazon\ncompany\n•\n20 models\n•\n3.27k followers\nGoogle\nEnterprise\ncompany\n•\n1.01k models\n•\n18.6k followers\nIntel\ncompany\n•\n206 models\n•\n2.7k followers\nMicrosoft\ncompany\n•\n396 models\n•\n13.3k followers\nGrammarly\nTeam\ncompany\n•\n10 models\n•\n166 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n309 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n146,433\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,639\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,338\nSafe way to store/distribute neural network weights\nHub Python Library\n2,734\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,864\nFast tokenizers optimized for research & production\nTRL\n14,448\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,977\nState-of-the-art ML running directly in your browser\nsmolagents\n20,900\nSmol library to build great agents in Python\nPEFT\n18,937\nParameter-efficient finetuning for large language models\nDatasets\n20,331\nAccess & share datasets for any ML ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'linkedin page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'github page', 'url': 'https://github.com/huggingface'}, {'type': 'discussion forum', 'url': 'https://discuss.huggingface.co'}]}
# # Hugging Face Brochure
#
# ## Company Overview
# Welcome to **Hugging Face**, the AI community building the future! We provide a collaborative platform where the machine learning community can create, discover, and share models, datasets, and applications. With over **1 million models** and **250,000 datasets**, Hugging Face is at the forefront of AI innovation.
#
# ### What We Offer
# - **Models**: Browse and deploy state-of-the-art machine learning models across various modalities, including text, images, videos, 3D, and more.
# - **Datasets**: Access and share an extensive collection of datasets tailored for multiple machine learning tasks.
# - **Spaces**: Collaborate and create applications easily on our user-friendly platform.
# - **Enterprise Solutions**: Tailored solutions for organizations, providing enterprise-grade security, support, and access controls.
#
# ## Customers and Community
# Hugging Face commands a strong following across industry leaders and academic institutions. More than **50,000 organizations** such as:
# - Google
# - Microsoft
# - Amazon
# - Meta
# - Grammarly
#
# These organizations leverage our resources to enhance their AI capabilities and drive innovation.
#
# ## Company Culture
# We pride ourselves on being an open and collaborative community. Our mission is to democratize AI, making it accessible for everyone. We foster an inclusive environment where collaboration is encouraged, ensuring continual growth and knowledge sharing.
#
# ### Values
# - **Collaboration**: Working together to drive advancements in machine learning.
# - **Open Source**: Believing that the best tools for AI should be freely accessible to everyone.
# - **User-Centric Approach**: Building our platforms and tools based on the needs and feedback of our community.
#
# ## Career Opportunities
# Join the Hugging Face team and be part of revolutionizing the AI landscape! We offer numerous career paths for individuals passionate about AI and machine learning. With roles ranging from engineering and research to marketing and community management, there's a place for everyone.
#
# ### Benefits of Working at Hugging Face:
# - Work in a dynamic and inclusive environment.
# - Engage in meaningful projects that make a real impact.
# - Access opportunities for personal and professional development.
#
# ## Join Us
# Discover the vast possibilities of AI with Hugging Face. Whether you are a developer, researcher, or simply interested in machine learning, we invite you to explore our offerings and become part of our community.
#
# **Sign up today** to start collaborating in the world of AI!
#
# ---
# **Contact Us**:
# For more information, visit our [website](https://huggingface.co), or follow us on our social channels:
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://linkedin.com/company/huggingface)
# - [Discord](https://discord.com/invite/huggingface)
#
# Hugging Face – Empowering the Future of AI!

# %% [markdown]
# ### Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# # Hugging Face Brochure
#
# ## Overview
# **Hugging Face** is an innovative AI community dedicated to building the future of machine learning (ML). Our platform enables seamless collaboration on **models, datasets, and applications**, making it the go-to place for AI enthusiasts, researchers, and companies alike.
#
# ### Our Mission
# At Hugging Face, we aim to **democratize AI** by providing the tools and support needed for anyone to create and innovate in the field of machine learning. Our open-source approach supports collaborative efforts and aims to share knowledge and techniques widely.
#
# ## Products and Services
#
# ### Models
# - Access **1M+ models** hosted on our platform, creating endless possibilities for application development.
# - Recent trending examples include innovative projects like black-forest-labs/FLUX.1, tencent/Hunyuan-A13B, and many more.
#
# ### Datasets
# - Browse through **250k+ datasets** tailored for various ML tasks, aiding researchers and AI developers in their projects.
#
# ### Spaces
# - Explore the latest **applications** through our Spaces feature, where users can run interactive AI applications directly within the platform.
#
# ### Enterprise Solutions
# - We offer **Compute and Enterprise solutions** for organizations, ensuring they can confidently deploy and manage their AI models with enterprise-grade security and support.
#
# ## Community Culture
# Hugging Face thrives on **collaboration, transparency, and open-source values.** Our community is made up of over **50,000 organizations**, including industry giants like Google, Amazon, and Microsoft. We encourage members to share experiences, tips, and tools through our platform.
#
# ### Get Involved
# - Join our vibrant community on platforms like Discord, GitHub, and Twitter.
# - Participate in discussions, contribute to projects, and stay updated with the latest advancements in AI.
#
# ## Careers at Hugging Face
# Hugging Face is growing rapidly, and we’re always on the lookout for passionate individuals who share our vision of advancing AI. Our company culture is defined by:
#
# - **Collaboration:** We believe that great ideas stem from teamwork and diverse perspectives.
# - **Growth:** Continuous learning is encouraged, offering opportunities to expand skills and knowledge.
# - **Impact:** Every team member is empowered to make meaningful contributions to projects that shape the future of technology.
#
# ### Join Us!
# We invite innovators and thinkers to explore career opportunities at Hugging Face. You can view our job openings directly on our [Careers Page](https://huggingface.co/jobs).
#
# ## Conclusion
# Hugging Face is not just a platform; it’s a **movement to democratize machine learning** and empower the next generation of AI developers and enthusiasts. Whether you're seeking to utilize our tools, join our community, or explore new career paths, Hugging Face is the place to be!
#
# Explore more at [Hugging Face](https://huggingface.co) today!
